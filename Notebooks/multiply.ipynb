# %%
A=5
B=3
C=6

def multiply_ab(a,b):
    return a*b

print(multiply_ab(A,B))
print(multiply_ab(B,C))
print(multiply_ab(A,C))
# Out:
# 15
# 18
# 30

# %%
def square(x):
    return multiply_ab(x,x)

print(square(A))
print(square(B))
print(square(C))
# Out:
# 25
# 9
# 36
